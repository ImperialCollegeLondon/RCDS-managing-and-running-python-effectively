# %% [markdown]
# # Markdown Cell
#
# This is a markdown cell. These can contain different effects:
#
# $ x = \frac{y}{z_{0}} $
#
# * Lists
# * With bulletpoints
#
#
#
# <center><img src='https://raw.githubusercontent.com/coolernato/Managing-and-Running-Python-Effectively/master/Examples/Notebooks/Jupiter.jpg' width=300/>
# <figcaption>Jupiter, not Jupyter</figcaption></center>
# </figure>

# %%
import sys

# An exclamation mark prefix runs commands in a terminal
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib

# Create  a plot of a sin function
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 100, 0.1)
y = np.sin(x)

# The output of this print statement will be displayed below the code cell. plt.show() is not required
plt.plot(x, y)
# Out:
# Requirement already satisfied: numpy in c:\users\cmcoo\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\cmcoo\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (4.28.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\cmcoo\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\cmcoo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: setuptools in c:\users\cmcoo\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\cmcoo\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)

# %%
# Commands beginning with a % are ipython magic commands https://ipython.readthedocs.io/en/stable/interactive/magics.html
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# np         module     <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sys        module     <module 'sys' (built-in)>
# x          ndarray    1000: 1000 elems, type `float64`, 8000 bytes
# y          ndarray    1000: 1000 elems, type `float64`, 8000 bytes
